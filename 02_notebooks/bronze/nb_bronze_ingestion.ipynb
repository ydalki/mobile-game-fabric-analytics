# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df_players = spark.read.json("Files/game_source/players/players.jsonl")
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 3, Finished, Available, Finished, False)

# %%
display(df_players)
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 9e607b6d-990f-45c2-8472-42e6198db9ed)

# %%
df_players.count()
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 5, Finished, Available, Finished, False)
# 50000

# %%
df_players.printSchema()
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 6, Finished, Available, Finished, False)
# root
#  |-- acquisition_channel: string (nullable = true)
#  |-- age_group: string (nullable = true)
#  |-- campaign_id: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- creative_experiment_group: string (nullable = true)
#  |-- creative_id: string (nullable = true)
#  |-- device_type: string (nullable = true)
#  |-- experiment_group: string (nullable = true)
#  |-- first_session_timestamp: string (nullable = true)
#  |-- install_date: string (nullable = true)
#  |-- platform: string (nullable = true)
#  |-- player_id: string (nullable = true)

# %%
df_players.show(5, truncate=False)
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 7, Finished, Available, Finished, False)
# +-------------------+---------+-----------+--------------+-------------------------+-----------+-----------+----------------+-----------------------+------------+--------+---------+
# |acquisition_channel|age_group|campaign_id|country       |creative_experiment_group|creative_id|device_type|experiment_group|first_session_timestamp|install_date|platform|player_id|
# +-------------------+---------+-----------+--------------+-------------------------+-----------+-----------+----------------+-----------------------+------------+--------+---------+
# |Organic            |25-34    |NULL       |United Kingdom|Not Applicable           |NULL       |Phone      |Treatment       |2026-01-15T00:11:00    |2026-01-15  |iOS     |P040356  |
# ...

# %%
df_players.write.format("delta").mode("overwrite").saveAsTable("players_raw")
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 8, Finished, Available, Finished, False)

# %%
df_purchases = spark.read.json("Files/game_source/purchases/purchases.jsonl")

print("Row count:", df_purchases.count())
df_purchases.printSchema()
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 12, Finished, Available, Finished, False)
# Row count: 3525
# root
#  |-- currency: string (nullable = true)
#  |-- days_since_install: long (nullable = true)
#  |-- player_id: string (nullable = true)
#  |-- price_usd: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- purchase_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
df_purchases.write.format("delta").mode("overwrite").saveAsTable("purchases_raw")
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 13, Finished, Available, Finished, False)

# %%
df_marketing = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv("Files/game_source/marketing_spend/marketing_spend.csv")
)

print("Row count:", df_marketing.count())
df_marketing.printSchema()
display(df_marketing.limit(5))
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 14, Finished, Available, Finished, False)
# Row count: 1973
# root
#  |-- date: date (nullable = true)
#  |-- acquisition_channel: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- campaign_id: string (nullable = true)
#  |-- creative_id: string (nullable = true)
#  |-- creative_type: string (nullable = true)
#  |-- creative_concept: string (nullable = true)
#  |-- campaign_objective: string (nullable = true)
#  |-- impressions: integer (nullable = true)
#  |-- clicks: integer (nullable = true)
#  |-- installs: integer (nullable = true)
#  |-- spend_usd: double (nullable = true)
# SynapseWidget(Synapse.DataFrame, 3d781ffb-2441-4860-b2ca-1d5df6bb8e25)

# %%
df_marketing.write.format("delta").mode("overwrite").saveAsTable("marketing_spend_raw")
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 15, Finished, Available, Finished, False)

# %%
df_ad_events = spark.read.json("Files/game_source/ad_events/")

print("Row count:", df_ad_events.count())
df_ad_events.printSchema()
display(df_ad_events.limit(5))
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 16, Finished, Available, Finished, False)
# Row count: 233037
# root
#  |-- ad_type: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- placement: string (nullable = true)
#  |-- player_id: string (nullable = true)
#  |-- revenue_usd: double (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
# SynapseWidget(Synapse.DataFrame, 7264660a-688c-4897-8429-9aa67af9f43d)

# %%
df_ad_events.write.format("delta").mode("overwrite").saveAsTable("ad_events_raw")
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 17, Finished, Available, Finished, False)

# %%
df_sessions = spark.read.json("Files/game_source/sessions/sessions.jsonl")

print("Row count:", df_sessions.count())
df_sessions.printSchema()
display(df_sessions.limit(5))
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 18, Finished, Available, Finished, False)
# Row count: 402936
# root
#  |-- days_since_install: long (nullable = true)
#  |-- player_id: string (nullable = true)
#  |-- session_duration_minutes: double (nullable = true)
#  |-- session_end: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- session_number: long (nullable = true)
#  |-- session_start: string (nullable = true)
# SynapseWidget(Synapse.DataFrame, 28bf573d-d4ae-4a4c-9fa2-7a9b71d65328)

# %%
df_sessions.write.format("delta").mode("overwrite").saveAsTable("sessions_raw")
# Out:
# StatementMeta(, fb2652f8-3226-4af1-8024-3fc9d29321db, 19, Finished, Available, Finished, False)

# %%
df_level_events = spark.read.json(
    "Files/game_source/level_events/"
)

print("Row count:", df_level_events.count())
df_level_events.printSchema()

display(df_level_events.limit(5))
# Out:
# StatementMeta(, 3b348f43-37a7-4607-a725-8b1870a2a995, 3, Finished, Available, Finished, False)
# Row count: 3741631
# root
#  |-- event_id: string (nullable = true)
#  |-- event_name: string (nullable = true)
#  |-- player_id: string (nullable = true)
#  |-- properties: struct (nullable = true)
#  |    |-- attempt_number: long (nullable = true)
#  |    |-- booster_used: boolean (nullable = true)
#  |    |-- client_build: string (nullable = true)
#  |    |-- level_number: long (nullable = true)
#  |    |-- moves_remaining: long (nullable = true)
#  |    |-- unexpected_debug_flag: boolean (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
# SynapseWidget(Synapse.DataFrame, 2ff7a9b7-c5ea-4f38-9288-9e203f2ed451)

# %%
df_level_events.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("level_events_raw")
# Out:
# StatementMeta(, 3b348f43-37a7-4607-a725-8b1870a2a995, 4, Finished, Available, Finished, False)
